# %%
import pandas as pd

# %%
train = pd.read_csv('train.csv')
target = train['SalePrice']
df = pd.read_csv('processed_train.csv')
data = df.join(target)

# %%
data.head()
# Out:
#    Unnamed: 0  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0           0        60.0         65.0   8450.0          7.0          5.0
# 1           1        20.0         80.0   9600.0          6.0          8.0
# 2           2        60.0         68.0  11250.0          7.0          5.0
# 3           3        70.0         60.0   9550.0          7.0          5.0
# 4           4        60.0         84.0  14260.0          8.0          5.0
#
#    YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1    ...      SaleType_New  \
# 0     2003.0        2003.0       196.0       706.0    ...                 0
# 1     1976.0        1976.0         0.0       978.0    ...                 0
# 2     2001.0        2002.0       162.0       486.0    ...                 0
# 3     1915.0        1970.0         0.0       216.0    ...                 0
# 4     2000.0        2000.0       350.0       655.0    ...                 0
#
# ...

# %%
from sklearn.model_selection import train_test_split
train_X, test_X, train_y, test_y = train_test_split(data.values, target.values, test_size = 0.25)

# %%
from xgboost import XGBRegressor
my_model = XGBRegressor(n_estimators = 1000, learning_rate = 0.05)
my_model.fit(train_X, train_y, early_stopping_rounds = 5, eval_set = [(test_X, test_y)], verbose = False)
test_predict = my_model.predict(test_X)

# %%
from sklearn.metrics import mean_absolute_error
print('Mean Absolute Error: ', str(mean_absolute_error(test_predict, test_y)))
# Out:
# Mean Absolute Error:  680.0814854452054
